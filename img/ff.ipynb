# %%
from PIL import Image

# لیست عکس‌ها (باید اندازه‌شون یکی باشه)
frames = [Image.open(img) for img in ["m1.jpg", "m2.jpg","m3.jpg","m4.jpg","m5.jpg","m6.jpg","m7.jpg"]]

# ذخیره به عنوان گیف
frames[0].save(
    "mm1.gif",
    save_all=True,
    append_images=frames[1:],
    duration=800,  # مدت هر فریم (میلی‌ثانیه)
    loop=0         # تعداد تکرار (0 = بی‌نهایت)
)
print("🐺")
# Out:
# 🐺
